# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.7 MB/s eta 0:00:01
# Collecting pytz>=2017.2
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 65.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /data/vision/torralba/frames/tools/anaconda3/envs/vh_challenge/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /data/vision/torralba/frames/tools/anaconda3/envs/vh_challenge/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /data/vision/torralba/frames/tools/anaconda3/envs/vh_challenge/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.0.1 pytz-2019.3

# %%
from baselines.common import plot_util as pu

# %% [markdown]
# If you want to average results for multiple seeds, LOG_DIRS must contain subfolders in the following format: ```<name_exp0>-0```, ```<name_exp0>-1```, ```<name_exp1>-0```, ```<name_exp1>-1```. Where names correspond to experiments you want to compare separated with random seeds by dash.

# %%
LOG_DIRS = 'logs/virtualhome/'
# Uncomment below to see the effect of the timit limits flag
#LOG_DIRS = 'time_limit_logs/reacher'

# %%
results = pu.load_results(LOG_DIRS)
# Out:
# /data/vision/torralba/frames/data_acquisition/SyntheticStories/MultiAgent/challenge/vh_multiagent_models/rl/baselines/baselines/bench/monitor.py:162: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
