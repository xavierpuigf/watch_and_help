# %% [markdown]
# # Interactive inference

# %%
from models.single_policy import SinglePolicy
from single_agent import SingleAgent
from IPython.display import SVG, display, HTML
import torch
from torch import distributions
import pdb
import vh_graph
import gym
import envdataset
import utils_viz
import utils
import sys
from IPython.display import Image
sys.argv = ['-f']

# %%
curr_env = gym.make('vh_graph-v0')

# %%
weights = 'logdir/dataset_folder.dataset_toy3_pomdp.False_graphsteps.3/2019-11-06_09.14.31.202175/chkpt/chkpt_49.pt'

# %%
# Set up the policy
args = utils.read_args()
args.max_steps = 1
args.interactive = True
dataset_interactive = envdataset.EnvDataset(args, process_progs=False)
print('Starting model...')
policy_net = SinglePolicy(dataset_interactive).cuda()
policy_net = torch.nn.DataParallel(policy_net)
policy_net.eval()
if weights is not None:
    print('Loading weights')
    state_dict = torch.load(weights)
    policy_net.load_state_dict(state_dict['model_params'])
# Out:
# Getting objects from dataset_toy3/obj_names.json...
# Starting model...
# Loading weights

# %%
path_init_env = 'dataset_toy3/init_envs/TrimmedTestScene6_graph_42.json'
goal_name = '(facing living_room[1] living_room[1])'
curr_env.reset(path_init_env, goal_name)
curr_env.to_pomdp()
single_agent = SingleAgent(curr_env, goal_name, 0, policy_net)

# Starting the scene
curr_state = single_agent.get_observations()
gt_state = single_agent.env.vh_state.to_dict()

# All the nodes
nodes, _, ids_used = dataset_interactive.process_graph(gt_state)
class_names, object_ids, _, mask_nodes, _ = nodes
# Out:
# Loading graph...
# Loaded

# %% [markdown]
# ### Set the goal to find pencil 2026

# %%
id_agent = [x['id'] for x in gt_state['nodes'] if x['class_name'] == 'character'][0]
id_goal = 2026
goal_str = 'findnode_{}'.format(id_goal)

# %% [markdown]
# ## View graph

# %%
graph = utils_viz.graph2im(gt_state, {id_goal: 'goal', id_agent: 'agent'})
graph.format = 'png'
tmp = graph.view()
display(Image(tmp))
# Out:
# Edges...

# %%
curr_state = single_agent.env.vh_state.to_dict()
visible_ids = single_agent.env.observable_object_ids

# %%
graph_data, action_logits, o1_logits, o2_logits = single_agent.obtain_logits_from_observations(
            dataset_interactive, curr_state, ids_used, visible_ids, class_names, object_ids, mask_nodes, goal_str)

instruction, _ = single_agent.sample_instruction(dataset_interactive, graph_data, action_logits, o1_logits, o2_logits)

# %%
instruction
# Out:
# (['walk'], [('home_office', 246)], [('no_obj', -1)])

# %% [markdown]
# ### Multiple step rollout

# %%
def one_step_rollout(env, goal_string, pomdp):
    if pomdp:
        curr_state = single_agent.get_observations()
        visible_ids = None
    else:
        curr_state = single_agent.env.vh_state.to_dict()
        visible_ids = single_agent.env.observable_object_ids
    
    graph_data, action_logits, o1_logits, o2_logits = single_agent.obtain_logits_from_observations(
            dataset_interactive, curr_state, ids_used, visible_ids, class_names, object_ids, mask_nodes, goal_string)
    instruction, logits = single_agent.sample_instruction(dataset_interactive, graph_data, 
                                                          action_logits, o1_logits, o2_logits, pick_max=True)
    #instruction = single_agent.get_top_instruction(dataset_interactive, graph_data, action_logits, o1_logits, o2_logits)
    logits = None
    instr = list(zip(*instruction))[0]
    str_instruction = utils.pretty_instr(instr)
    if 'stop' in str_instruction:
            return None, str_instruction, logits
    resp = single_agent.env.step(str_instruction)
    return resp, str_instruction, logits

# %%
args.pomdp = False
weights = 'logdir/dataset_folder.dataset_toy3_pomdp.False_graphsteps.3/2019-11-06_09.14.31.202175/chkpt/chkpt_49.pt'
state_dict = torch.load(weights)
single_agent.policy_net.load_state_dict(state_dict['model_params'])

curr_env.reset(path_init_env, goal_name)
max_instr = 0
instr = ''
goal_str = 'findnode_315'
while max_instr < 10 and 'stop' not in instr:
    a = one_step_rollout(single_agent.env, goal_str, args.pomdp)
    instr = a[1]
    max_instr += 1
    print(instr)
# Out:
# Loading graph...
# Loaded
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-70c9cfe2b234> in <module>
#       9 goal_str = 'findnode_315'
#      10 while max_instr < 10 and 'stop' not in instr:
# ---> 11     a = one_step_rollout(single_agent.env, goal_str, args.pomdp)
#      12     instr = a[1]
#      13     max_instr += 1
#
# <ipython-input-88-4d3dd88aec06> in one_step_rollout(env, goal_string, pomdp)
#      10             dataset_interactive, curr_state, ids_used, visible_ids, class_names, object_ids, mask_nodes, goal_string)
#      11     instruction, logits = single_agent.sample_instruction(dataset_interactive, graph_data,
# ---> 12                                                           action_logits, o1_logits, o2_logits, pick_max=True)
#      13     #instruction = single_agent.get_top_instruction(dataset_interactive, graph_data, action_logits, o1_logits, o2_logits)
#      14     logits = None
#
# TypeError: sample_instruction() got an unexpected keyword argument 'pick_max'

# %%
curr_env.reset(path_init_env, goal_name)
max_instr = 0
instr = ''
goal_str = 'findnode_301'
while max_instr < 10 and 'stop' not in instr:
    a = one_step_rollout(single_agent.env, goal_str, args.pomdp)
    instr = a[1]
    max_instr += 1
    print(instr)
# Out:
# Loading graph...
# Loaded
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-59e77ff41807> in <module>
#       4 goal_str = 'findnode_301'
#       5 while max_instr < 10 and 'stop' not in instr:
# ----> 6     a = one_step_rollout(single_agent.env, goal_str, args.pomdp)
#       7     instr = a[1]
#       8     max_instr += 1
#
# <ipython-input-88-4d3dd88aec06> in one_step_rollout(env, goal_string, pomdp)
#      10             dataset_interactive, curr_state, ids_used, visible_ids, class_names, object_ids, mask_nodes, goal_string)
#      11     instruction, logits = single_agent.sample_instruction(dataset_interactive, graph_data,
# ---> 12                                                           action_logits, o1_logits, o2_logits, pick_max=True)
#      13     #instruction = single_agent.get_top_instruction(dataset_interactive, graph_data, action_logits, o1_logits, o2_logits)
#      14     logits = None
#
# TypeError: sample_instruction() got an unexpected keyword argument 'pick_max'

# %% [markdown]
# ### Back to non POMDP

# %%
# %autoreload 2
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
path_init_env = "dataset_toy3/init_envs/TrimmedTestScene6_graph_19.json"
goal_name = '(facing living_room[1] living_room[1])'
curr_env.reset(path_init_env, goal_name)
curr_env.to_pomdp()
single_agent = SingleAgent(curr_env, goal_name, 0, policy_net)

# Starting the scene
curr_state = single_agent.get_observations()
gt_state = single_agent.env.vh_state.to_dict()

# All the nodes
nodes, _, ids_used = dataset_interactive.process_graph(gt_state)
class_names, object_ids, _, mask_nodes, _ = nodes
# Out:
# Loading graph...
# Loaded

# %%
graph = utils_viz.graph2im(gt_state, {2009: 'goal', id_agent: 'agent'})
graph.format = 'png'
tmp = graph.view()
display(Image(tmp))
# Out:
# Edges...

# %%
args.pomdp = False
weights = 'logdir/dataset_folder.dataset_toy3_pomdp.False_graphsteps.3/2019-11-06_09.14.31.202175/chkpt/chkpt_49.pt'
state_dict = torch.load(weights)
single_agent.policy_net.load_state_dict(state_dict['model_params'])
curr_env.reset(path_init_env, goal_name)
max_instr = 0
instr = ''
goal_str = 'findnode_2009'
while max_instr < 10 and 'stop' not in instr:
    a = one_step_rollout(single_agent.env, goal_str, args.pomdp)
    instr = a[1]
    max_instr += 1
    print(instr)
# Out:
# Loading graph...
# Loaded
# [walk] <plate> (2009)
# [stop]

# %%
args.pomdp = True
weights = 'logdir/dataset_folder.dataset_toy3_pomdp.True_graphsteps.3/2019-11-06_09.13.35.555005/chkpt/chkpt_49.pt'
state_dict = torch.load(weights)
single_agent.policy_net.load_state_dict(state_dict['model_params'])
curr_env.reset(path_init_env, goal_name)
max_instr = 0
instr = ''
goal_str = 'findnode_2009'
while max_instr < 10 and 'stop' not in instr:
    a = one_step_rollout(single_agent.env, goal_str, args.pomdp)
    instr = a[1]
    max_instr += 1
    print(instr)
# Out:
# Loading graph...
# Loaded
# [walk] <freezer> (234)
# [open] <freezer> (234)
# [stop]

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
